# %%
def is_part_of_graph (x, y, a, b, c, d, e):
	if a*x*x*x*x + b*x*x*x + c*x*x + d*x + e < y+0.75 and a*x*x*x*x + b*x*x*x + c*x*x + d*x + e > y-0.75:
		return 1
	else:
		return 0
def derivative(a, b, c, d):
	if a==0:
		if b==0:
			if c==0:   
				print("The derivative of the given function is: yd = "+str(d))
			else:
				print("The derivative of the given function is: yd = "+str(2*c)+"x + "+str(d))
		else:
			print("The derivative of the given function is: yd = "+str(3*b)+"x^2 + "+str(2*c)+"x + "+str(d))
	else:
		print("The derivative of the given function is: yd = "+str(4*a)+"x^3 + "+str(3*b)+"x^2 + "+str(2*c)+"x + "+str(d))
def your_equation(a, b, c, d, e):
	if a==0:
		if b==0:
			if c==0:
				if d==0:
					print("The given function is: y = "+str(e))
				else:
					print("The given function is: y = "+str(d)+"x + "+str(e))
			else:
				print("The given function is: y = "+str(c)+"x^2 + "+str(d)+"x + "+str(e))
		else:
			print("The given function is: y = "+str(b)+"x^3 + "+str(c)+"x^2 + "+str(d)+"x + "+str(e))
	else:
		print("The given function is: y = "+str(a)+"x^4 + "+str(b)+"x^3 + "+str(c)+"x^2 + "+str(d)+"x + "+str(e))
	print("  The equation: f(x) = ax^4 + bx^3 + cx^2 + dx + e \n")
	print("Enter the coefficients of the equation \n")
a=int(input())
b=int(input())
c=int(input())
d=int(input())
e=int(input())
your_equation(a, b, c, d, e)
print("\n")
derivative(a, b, c, d)
print("\n")
for y in range(20,-20):
	for x in range(-20,20):
		if y>0:
			if is_part_of_graph(x, y, a, b, c, d, e)==1:
				if x==0:
					print("  *")
				else:
					print(" *")
			elif x>0:
				print("  ")
			elif x<0:
				print("  ")
			elif x==0:
				if y==int(y):
					if y==10:
						print(" "+str(y)+" ")
					else:
						print("  "+str(y)+" ")
				else:
					print("  | ")
		elif y<0:
			if is_part_of_graph(x, y, a, b, c, d, e)==1:
				if x==0:
					print("  *")
				else:
					print(" *")
			elif x>0:
				print("  ")
			elif x<0:
				print("  ")
			elif x==0:
				if y==int(y):
					if y==20:
						print(str(y)+" ")
					else:
						print(" "+str(y)+" ")
				else:
					print("  | ")
		elif y==0:
			if is_part_of_graph( x, y, a, b, c, d, e)==1:
				print(" *")
			else:
				if x==int(x):
					if x<0:
						print(str(x))
					elif x>0:
						print("-"+str(x))
					else:
						print("+O+")
				else:
					print("--")
	print("\n")
# Out:
# The given function is: y = 2x + 1
#   The equation: f(x) = ax^4 + bx^3 + cx^2 + dx + e
#
# Enter the coefficients of the equation
#
#
#
# The derivative of the given function is: yd = 2
