# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC','^IXIC','^GDAXI','^DJI']
ind_data = pd.DataFrame()
for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source = 'yahoo', start = '1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI         ^DJI
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059  6442.490234
# 1997-01-03  748.030029  1310.680054  2863.260010  6544.089844
# 1997-01-06  747.650024  1316.400024  2890.199951  6567.180176
# 1997-01-07  753.229980  1327.729980  2876.340088  6600.660156
# 1997-01-08  748.409973  1320.349976  2904.080078  6549.479980

# %%
ind_data.tail()
# Out:
#                   ^GSPC        ^IXIC        ^GDAXI          ^DJI
# Date
# 2020-05-04  2842.739990  8710.709961  10466.799805  23749.759766
# 2020-05-05  2868.439941  8809.120117  10729.459961  23883.089844
# 2020-05-06  2848.419922  8854.389648  10606.200195  23664.640625
# 2020-05-07  2881.189941  8979.660156  10759.269531  23875.890625
# 2020-05-08  2929.800049  9121.320312  10904.480469  24331.320312

# %%
(ind_data/ind_data.iloc[0] * 100).plot(figsize=(15,6))
plt.show()

# %%
ind_returns = (ind_data/ind_data.shift(1))-1
ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI      ^DJI
# Date
# 2020-05-04  0.004250  0.012291       NaN  0.001099
# 2020-05-05  0.009041  0.011298  0.025095  0.005614
# 2020-05-06 -0.006979  0.005139 -0.011488 -0.009147
# 2020-05-07  0.011505  0.014148  0.014432  0.008927
# 2020-05-08  0.016872  0.015776  0.013496  0.019075

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.078172
# ^IXIC     0.115460
# ^GDAXI    0.072082
# ^DJI      0.074465
# dtype: float64

# %%
tickers = ['PG', '^GSPC', '^DJI']
data_2 = pd.DataFrame()
for t in tickers:
    data_2[t] = wb.DataReader(t, data_source = 'yahoo', start = '2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                     PG        ^GSPC          ^DJI
# Date
# 2020-05-04  115.769997  2842.739990  23749.759766
# 2020-05-05  116.010002  2868.439941  23883.089844
# 2020-05-06  113.099998  2848.419922  23664.640625
# 2020-05-07  112.169998  2881.189941  23875.890625
# 2020-05-08  115.949997  2929.800049  24331.320312

# %%
(data_2/data_2.iloc[0] * 100).plot(figsize=(15, 6))
plt.show()
