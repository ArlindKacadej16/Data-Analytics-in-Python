# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['PG','BEI.DE']

sec_data = pd.DataFrame()

for t in tickers:
    sec_data[t] = wb.DataReader(t, data_source='yahoo', start='2007-1-1')['Adj Close']

# %%
sec_data.tail()
# Out:
#                     PG     BEI.DE
# Date
# 2020-05-05  116.010002  89.279999
# 2020-05-06  113.099998  91.000000
# 2020-05-07  112.169998  92.239998
# 2020-05-08  115.949997  94.279999
# 2020-05-11  115.309998  94.680000

# %%
sec_returns = np.log(sec_data / sec_data.shift(1))
sec_returns
# Out:
#                   PG    BEI.DE
# Date
# 2007-01-03       NaN       NaN
# 2007-01-04 -0.007621  0.006544
# 2007-01-05 -0.008624 -0.020772
# 2007-01-08  0.002202  0.000202
# 2007-01-09 -0.002517 -0.022858
# 2007-01-10  0.011901 -0.012673
# 2007-01-11  0.006207  0.007498
# 2007-01-12  0.005554  0.009295
# 2007-01-16  0.000000  0.024573
# 2007-01-17  0.010304 -0.041784
# 2007-01-18  0.002750  0.011024
# 2007-01-19  0.008357 -0.002071
# 2007-01-22 -0.005614 -0.000830
# 2007-01-23 -0.001218  0.001037
# 2007-01-24 -0.001982  0.013382
# 2007-01-25 -0.009047 -0.019619
# 2007-01-26 -0.000925  0.000209
# 2007-01-29  0.000309  0.013050
# 2007-01-30 -0.004480  0.026202
# 2007-01-31  0.004326  0.032932
# 2007-02-01  0.007219 -0.010923
# 2007-02-02  0.000000  0.007035
# 2007-02-05 -0.002912  0.000973
# 2007-02-06 -0.008633 -0.004876
# 2007-02-07 -0.001704 -0.000391
# 2007-02-08  0.001704 -0.010617
# 2007-02-09 -0.002481  0.001777
# 2007-02-12 -0.004199 -0.000987
# 2007-02-13  0.008536  0.001382
# 2007-02-14  0.002624  0.012934
# ...              ...       ...
# 2020-03-30  0.042908  0.022250
# 2020-03-31 -0.044452 -0.011387
# 2020-04-01 -0.006110 -0.043274
# 2020-04-02  0.045330  0.010995
# 2020-04-03  0.005926  0.001115
# 2020-04-06  0.023446  0.003560
# 2020-04-07 -0.043723  0.009726
# 2020-04-08  0.020451 -0.011282
# 2020-04-09 -0.003830  0.016548
# 2020-04-13  0.011188       NaN
# 2020-04-14  0.042301       NaN
# 2020-04-15  0.002147 -0.013672
# 2020-04-16  0.002307  0.003864
# 2020-04-17  0.025916  0.012986
# 2020-04-20 -0.033351  0.011775
# 2020-04-21 -0.007658  0.002088
# 2020-04-22 -0.002342  0.000626
# 2020-04-23  0.006647 -0.005854
# 2020-04-24 -0.005206 -0.006311
# 2020-04-27 -0.011260 -0.003594
# 2020-04-28 -0.004779  0.004859
# 2020-04-29  0.001624  0.002315
# 2020-04-30  0.006725  0.012211
# 2020-05-01 -0.008948       NaN
# 2020-05-04 -0.009029       NaN
# 2020-05-05  0.002071 -0.028924
# 2020-05-06 -0.025404  0.019082
# 2020-05-07 -0.008257  0.013534
# 2020-05-08  0.033143  0.021875
# 2020-05-11 -0.005535  0.004234
#
# [3362 rows x 2 columns]

# %%
sec_returns.plot(figsize=(15,6))
plt.show()

# %%
sec_returns.mean()
# Out:
# PG        0.000292
# BEI.DE    0.000248
# dtype: float64

# %%
sec_returns.mean() * 250
# Out:
# PG        0.073118
# BEI.DE    0.061981
# dtype: float64

# %%
sec_returns.std()
# Out:
# PG        0.011958
# BEI.DE    0.013774
# dtype: float64

# %%
sec_returns.std() * 250**0.5
# Out:
# PG        0.18908
# BEI.DE    0.21778
# dtype: float64
